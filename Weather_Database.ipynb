# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 607

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Make a 'Get' request for the city weather.

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | isangel
# Processing Record 3 of Set 1 | luderitz
# Processing Record 4 of Set 1 | malyye derbety
# Processing Record 5 of Set 1 | hithadhoo
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | roald
# Processing Record 8 of Set 1 | atuona
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | sayyan
# Processing Record 12 of Set 1 | la plata
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | provideniya
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 1 | shetpe
# Processing Record 21 of Set 1 | deputatskiy
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | solnechnyy
# Processing Record 24 of Set 1 | souris
# Processing Record 25 of Set 1 | rijeka
# Processing Record 26 of Set 1 | beloha
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | port-gentil
# Processing Record 29 of Set 1 | port elizabeth
# Processing Record 30 of Set 1 | sao filipe
# Processing Record 31 of Set 1 | saint anthony
# Processing Record 32 of Set 1 | severo-kurilsk
# Processing Record 33 of Set 1 | sawakin
# Processing Record 34 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | yulara
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | bethel
# Processing Record 39 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 40 of Set 1 | pevek
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | barrow
# Processing Record 43 of Set 1 | ismailia
# Processing Record 44 of Set 1 | aswan
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | senneterre
# Processing Record 47 of Set 1 | coihaique
# Processing Record 48 of Set 1 | alofi
# Processing Record 49 of Set 1 | butaritari
# Processing Record 50 of Set 1 | hasaki
# Processing Record 1 of Set 2 | victoria
# Processing Record 2 of Set 2 | margate
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | kruisfontein
# Processing Record 5 of Set 2 | tautira
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | kangaba
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | nelson bay
# Processing Record 10 of Set 2 | springfield
# Processing Record 11 of Set 2 | saint george
# Processing Record 12 of Set 2 | maxixe
# Processing Record 13 of Set 2 | fortuna
# Processing Record 14 of Set 2 | namibe
# Processing Record 15 of Set 2 | norman wells
# Processing Record 16 of Set 2 | jalu
# Processing Record 17 of Set 2 | sao joao da barra
# Processing Record 18 of Set 2 | qaanaaq
# Processing Record 19 of Set 2 | san ignacio
# Processing Record 20 of Set 2 | harper
# Processing Record 21 of Set 2 | kiama
# Processing Record 22 of Set 2 | hoquiam
# Processing Record 23 of Set 2 | fort nelson
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | port hedland
# Processing Record 26 of Set 2 | chuy
# Processing Record 27 of Set 2 | katsuura
# Processing Record 28 of Set 2 | kalangala
# Processing Record 29 of Set 2 | kaili
# Processing Record 30 of Set 2 | anadyr
# Processing Record 31 of Set 2 | goundi
# Processing Record 32 of Set 2 | kodiak
# Processing Record 33 of Set 2 | antofagasta
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | jamestown
# Processing Record 36 of Set 2 | kaitangata
# Processing Record 37 of Set 2 | guerrero negro
# Processing Record 38 of Set 2 | maneadero
# Processing Record 39 of Set 2 | sobolevo
# Processing Record 40 of Set 2 | pacific grove
# Processing Record 41 of Set 2 | bengkulu
# Processing Record 42 of Set 2 | pangnirtung
# Processing Record 43 of Set 2 | loa janan
# Processing Record 44 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 2 | arvika
# Processing Record 46 of Set 2 | punta arenas
# Processing Record 47 of Set 2 | santa rosa del sur
# Processing Record 48 of Set 2 | khandyga
# Processing Record 49 of Set 2 | richards bay
# Processing Record 50 of Set 2 | bereda
# Processing Record 1 of Set 3 | labytnangi
# Processing Record 2 of Set 3 | yellowknife
# Processing Record 3 of Set 3 | bambous virieux
# Processing Record 4 of Set 3 | dingle
# Processing Record 5 of Set 3 | puerto ayora
# Processing Record 6 of Set 3 | dikson
# Processing Record 7 of Set 3 | hervey bay
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | bluff
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | takoradi
# Processing Record 14 of Set 3 | carnarvon
# Processing Record 15 of Set 3 | torbay
# Processing Record 16 of Set 3 | ningbo
# Processing Record 17 of Set 3 | vardo
# Processing Record 18 of Set 3 | havoysund
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | poum
# Processing Record 21 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 3 | los chiles
# Processing Record 23 of Set 3 | kedrovyy
# Processing Record 24 of Set 3 | jinchang
# Processing Record 25 of Set 3 | ystad
# Processing Record 26 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 3 | lavrentiya
# Processing Record 28 of Set 3 | vung tau
# Processing Record 29 of Set 3 | alto parana
# Processing Record 30 of Set 3 | petrozavodsk
# Processing Record 31 of Set 3 | ossora
# Processing Record 32 of Set 3 | teruel
# Processing Record 33 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 3 | kathmandu
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | clyde river
# Processing Record 37 of Set 3 | ilulissat
# Processing Record 38 of Set 3 | pravda
# Processing Record 39 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 3 | anaconda
# Processing Record 41 of Set 3 | orumiyeh
# Processing Record 42 of Set 3 | paamiut
# Processing Record 43 of Set 3 | rio gallegos
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | rio de janeiro
# Processing Record 46 of Set 3 | preobrazheniye
# Processing Record 47 of Set 3 | la ronge
# Processing Record 48 of Set 3 | rosarito
# Processing Record 49 of Set 3 | zima
# Processing Record 50 of Set 3 | poya
# Processing Record 1 of Set 4 | daan
# Processing Record 2 of Set 4 | saskylakh
# Processing Record 3 of Set 4 | hermanus
# Processing Record 4 of Set 4 | noumea
# Processing Record 5 of Set 4 | east london
# Processing Record 6 of Set 4 | humberto de campos
# Processing Record 7 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 4 | lyngseidet
# Processing Record 9 of Set 4 | bismarck
# Processing Record 10 of Set 4 | padang
# Processing Record 11 of Set 4 | mayumba
# Processing Record 12 of Set 4 | ulladulla
# Processing Record 13 of Set 4 | lagoa
# Processing Record 14 of Set 4 | olhao
# Processing Record 15 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 16 of Set 4 | hofn
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | mahebourg
# Processing Record 19 of Set 4 | port alfred
# Processing Record 20 of Set 4 | sorland
# Processing Record 21 of Set 4 | flin flon
# Processing Record 22 of Set 4 | aden
# Processing Record 23 of Set 4 | alamor
# Processing Record 24 of Set 4 | alice springs
# Processing Record 25 of Set 4 | shiogama
# Processing Record 26 of Set 4 | ozernovskiy
# Processing Record 27 of Set 4 | idlib
# Processing Record 28 of Set 4 | barcelona
# Processing Record 29 of Set 4 | purwodadi
# Processing Record 30 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 31 of Set 4 | mao
# Processing Record 32 of Set 4 | glendive
# Processing Record 33 of Set 4 | lichinga
# Processing Record 34 of Set 4 | mildura
# Processing Record 35 of Set 4 | san patricio
# Processing Record 36 of Set 4 | asfi
# Processing Record 37 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 4 | geraldton
# Processing Record 39 of Set 4 | acambay
# Processing Record 40 of Set 4 | aklavik
# Processing Record 41 of Set 4 | shkotovo-26
# City not found. Skipping...
# Processing Record 42 of Set 4 | bubaque
# Processing Record 43 of Set 4 | naze
# Processing Record 44 of Set 4 | botiz
# Processing Record 45 of Set 4 | bandarbeyla
# Processing Record 46 of Set 4 | san policarpo
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | grindavik
# Processing Record 49 of Set 4 | tornio
# Processing Record 50 of Set 4 | santander
# Processing Record 1 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 5 | leningradskiy
# Processing Record 3 of Set 5 | achisay
# City not found. Skipping...
# Processing Record 4 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 5 of Set 5 | tupik
# Processing Record 6 of Set 5 | leirvik
# Processing Record 7 of Set 5 | yining
# Processing Record 8 of Set 5 | ulaanbaatar
# Processing Record 9 of Set 5 | new norfolk
# Processing Record 10 of Set 5 | inirida
# Processing Record 11 of Set 5 | ribeira grande
# Processing Record 12 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 5 | duz
# City not found. Skipping...
# Processing Record 14 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 5 | verbivka
# Processing Record 16 of Set 5 | amga
# Processing Record 17 of Set 5 | ban nahin
# Processing Record 18 of Set 5 | sechura
# Processing Record 19 of Set 5 | robertsport
# Processing Record 20 of Set 5 | valverde del camino
# Processing Record 21 of Set 5 | zyryanka
# Processing Record 22 of Set 5 | fort-de-france
# Processing Record 23 of Set 5 | okhotsk
# Processing Record 24 of Set 5 | bredasdorp
# Processing Record 25 of Set 5 | kongolo
# Processing Record 26 of Set 5 | nouadhibou
# Processing Record 27 of Set 5 | saldanha
# Processing Record 28 of Set 5 | korla
# Processing Record 29 of Set 5 | pisco
# Processing Record 30 of Set 5 | cuenca
# Processing Record 31 of Set 5 | tutoia
# Processing Record 32 of Set 5 | cooma
# Processing Record 33 of Set 5 | rocha
# Processing Record 34 of Set 5 | port blair
# Processing Record 35 of Set 5 | luis moya
# Processing Record 36 of Set 5 | lubao
# Processing Record 37 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 5 | ola
# Processing Record 39 of Set 5 | dingli
# Processing Record 40 of Set 5 | olafsvik
# Processing Record 41 of Set 5 | alghero
# Processing Record 42 of Set 5 | namatanai
# Processing Record 43 of Set 5 | nybro
# Processing Record 44 of Set 5 | north platte
# Processing Record 45 of Set 5 | aktau
# Processing Record 46 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 47 of Set 5 | havre-saint-pierre
# Processing Record 48 of Set 5 | saint-joseph
# Processing Record 49 of Set 5 | angoche
# Processing Record 50 of Set 5 | beira
# Processing Record 1 of Set 6 | tiruchchendur
# Processing Record 2 of Set 6 | huarmey
# Processing Record 3 of Set 6 | ayan
# Processing Record 4 of Set 6 | lindi
# Processing Record 5 of Set 6 | broome
# Processing Record 6 of Set 6 | palmer
# Processing Record 7 of Set 6 | albina
# Processing Record 8 of Set 6 | cordoba
# Processing Record 9 of Set 6 | iqaluit
# Processing Record 10 of Set 6 | shitanjing
# Processing Record 11 of Set 6 | necochea
# Processing Record 12 of Set 6 | nioro
# Processing Record 13 of Set 6 | palauig
# Processing Record 14 of Set 6 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 6 | champerico
# Processing Record 16 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 6 | chumikan
# Processing Record 18 of Set 6 | faya
# Processing Record 19 of Set 6 | mount pleasant
# Processing Record 20 of Set 6 | mehriz
# Processing Record 21 of Set 6 | qaqortoq
# Processing Record 22 of Set 6 | tome
# Processing Record 23 of Set 6 | chunhuhub
# Processing Record 24 of Set 6 | sioux lookout
# Processing Record 25 of Set 6 | cajetina
# Processing Record 26 of Set 6 | ajdabiya
# Processing Record 27 of Set 6 | kahului
# Processing Record 28 of Set 6 | biak
# Processing Record 29 of Set 6 | cabinda
# Processing Record 30 of Set 6 | baherden
# Processing Record 31 of Set 6 | abnub
# Processing Record 32 of Set 6 | puerto escondido
# Processing Record 33 of Set 6 | bukama
# Processing Record 34 of Set 6 | seymour
# Processing Record 35 of Set 6 | trinidad
# Processing Record 36 of Set 6 | souillac
# Processing Record 37 of Set 6 | gigmoto
# Processing Record 38 of Set 6 | daru
# Processing Record 39 of Set 6 | makakilo city
# Processing Record 40 of Set 6 | ponta do sol
# Processing Record 41 of Set 6 | sisimiut
# Processing Record 42 of Set 6 | nsoko
# Processing Record 43 of Set 6 | cidreira
# Processing Record 44 of Set 6 | olbia
# Processing Record 45 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 46 of Set 6 | tashara
# Processing Record 47 of Set 6 | silver city
# Processing Record 48 of Set 6 | shingu
# Processing Record 49 of Set 6 | chinhoyi
# Processing Record 50 of Set 6 | cairns
# Processing Record 1 of Set 7 | beyneu
# Processing Record 2 of Set 7 | prieska
# Processing Record 3 of Set 7 | brakel
# Processing Record 4 of Set 7 | namwala
# Processing Record 5 of Set 7 | vettavalam
# Processing Record 6 of Set 7 | khatanga
# Processing Record 7 of Set 7 | santa ana
# Processing Record 8 of Set 7 | talaya
# Processing Record 9 of Set 7 | nanortalik
# Processing Record 10 of Set 7 | ancud
# Processing Record 11 of Set 7 | port keats
# Processing Record 12 of Set 7 | aleksandrovskoye
# Processing Record 13 of Set 7 | prince rupert
# Processing Record 14 of Set 7 | port hardy
# Processing Record 15 of Set 7 | uvalde
# Processing Record 16 of Set 7 | ciudad bolivar
# Processing Record 17 of Set 7 | big rapids
# Processing Record 18 of Set 7 | tilichiki
# Processing Record 19 of Set 7 | karamay
# City not found. Skipping...
# Processing Record 20 of Set 7 | hun
# Processing Record 21 of Set 7 | aykhal
# Processing Record 22 of Set 7 | gunjur
# Processing Record 23 of Set 7 | comodoro rivadavia
# Processing Record 24 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 25 of Set 7 | buala
# Processing Record 26 of Set 7 | saint-georges
# Processing Record 27 of Set 7 | waterloo
# Processing Record 28 of Set 7 | belmonte
# Processing Record 29 of Set 7 | hamilton
# Processing Record 30 of Set 7 | zuenoula
# Processing Record 31 of Set 7 | reconquista
# Processing Record 32 of Set 7 | the valley
# Processing Record 33 of Set 7 | shenxian
# Processing Record 34 of Set 7 | nome
# Processing Record 35 of Set 7 | araouane
# Processing Record 36 of Set 7 | novaya ladoga
# Processing Record 37 of Set 7 | minab
# Processing Record 38 of Set 7 | mattru
# Processing Record 39 of Set 7 | casper
# Processing Record 40 of Set 7 | akyab
# Processing Record 41 of Set 7 | kangundo
# Processing Record 42 of Set 7 | antigonish
# Processing Record 43 of Set 7 | camargo
# Processing Record 44 of Set 7 | berdigestyakh
# Processing Record 45 of Set 7 | iskateley
# Processing Record 46 of Set 7 | wanning
# Processing Record 47 of Set 7 | lerwick
# Processing Record 48 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 49 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 50 of Set 7 | longyearbyen
# Processing Record 1 of Set 8 | sola
# Processing Record 2 of Set 8 | coahuayana
# Processing Record 3 of Set 8 | altea
# Processing Record 4 of Set 8 | gourcy
# Processing Record 5 of Set 8 | filingue
# Processing Record 6 of Set 8 | kombissiri
# Processing Record 7 of Set 8 | selu
# Processing Record 8 of Set 8 | verkhnevilyuysk
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | yamada
# Processing Record 11 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 12 of Set 8 | palimbang
# Processing Record 13 of Set 8 | pangody
# Processing Record 14 of Set 8 | kurchatov
# Processing Record 15 of Set 8 | talnakh
# Processing Record 16 of Set 8 | pangkalanbuun
# Processing Record 17 of Set 8 | nanlong
# Processing Record 18 of Set 8 | sigulda
# Processing Record 19 of Set 8 | chernyshevskiy
# Processing Record 20 of Set 8 | vestmanna
# Processing Record 21 of Set 8 | soyo
# Processing Record 22 of Set 8 | tabas
# Processing Record 23 of Set 8 | hokitika
# Processing Record 24 of Set 8 | mount gambier
# Processing Record 25 of Set 8 | vao
# Processing Record 26 of Set 8 | kavaratti
# Processing Record 27 of Set 8 | plered
# City not found. Skipping...
# Processing Record 28 of Set 8 | nantucket
# Processing Record 29 of Set 8 | yar-sale
# Processing Record 30 of Set 8 | saint-augustin
# Processing Record 31 of Set 8 | kotovo
# Processing Record 32 of Set 8 | ostrovnoy
# Processing Record 33 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | turtkul
# City not found. Skipping...
# Processing Record 35 of Set 8 | adrar
# Processing Record 36 of Set 8 | ferrol
# Processing Record 37 of Set 8 | sabang
# Processing Record 38 of Set 8 | varnavino
# Processing Record 39 of Set 8 | firovo
# Processing Record 40 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 8 | bambanglipuro
# Processing Record 42 of Set 8 | beysehir
# Processing Record 43 of Set 8 | chiria
# Processing Record 44 of Set 8 | tazovskiy
# Processing Record 45 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 46 of Set 8 | georgetown
# Processing Record 47 of Set 8 | broken hill
# Processing Record 48 of Set 8 | nove straseci
# Processing Record 49 of Set 8 | vanimo
# Processing Record 50 of Set 8 | jiancheng
# Processing Record 1 of Set 9 | waipawa
# Processing Record 2 of Set 9 | mankono
# Processing Record 3 of Set 9 | killybegs
# Processing Record 4 of Set 9 | praia da vitoria
# Processing Record 5 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 9 | arkhara
# Processing Record 7 of Set 9 | faanui
# Processing Record 8 of Set 9 | seminole
# Processing Record 9 of Set 9 | ambilobe
# Processing Record 10 of Set 9 | coquimbo
# Processing Record 11 of Set 9 | nabire
# Processing Record 12 of Set 9 | vila velha
# Processing Record 13 of Set 9 | samarai
# Processing Record 14 of Set 9 | raudeberg
# Processing Record 15 of Set 9 | nhamunda
# Processing Record 16 of Set 9 | show low
# Processing Record 17 of Set 9 | kontagora
# Processing Record 18 of Set 9 | kudat
# Processing Record 19 of Set 9 | cascais
# Processing Record 20 of Set 9 | san cristobal
# Processing Record 21 of Set 9 | puerto penasco
# Processing Record 22 of Set 9 | suntar
# Processing Record 23 of Set 9 | monitos
# Processing Record 24 of Set 9 | forrest city
# Processing Record 25 of Set 9 | cabo san lucas
# Processing Record 26 of Set 9 | beringovskiy
# Processing Record 27 of Set 9 | abu samrah
# Processing Record 28 of Set 9 | katangli
# Processing Record 29 of Set 9 | aksay
# Processing Record 30 of Set 9 | oranjemund
# Processing Record 31 of Set 9 | raver
# Processing Record 32 of Set 9 | hvide sande
# Processing Record 33 of Set 9 | orikum
# Processing Record 34 of Set 9 | wasilla
# Processing Record 35 of Set 9 | haines junction
# Processing Record 36 of Set 9 | tuatapere
# Processing Record 37 of Set 9 | komsomolskiy
# Processing Record 38 of Set 9 | tabuk
# Processing Record 39 of Set 9 | gold coast
# Processing Record 40 of Set 9 | axim
# Processing Record 41 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 42 of Set 9 | providencia
# Processing Record 43 of Set 9 | aksarka
# Processing Record 44 of Set 9 | cherskiy
# Processing Record 45 of Set 9 | fukue
# Processing Record 46 of Set 9 | hualmay
# Processing Record 47 of Set 9 | valleyview
# Processing Record 48 of Set 9 | cururupu
# Processing Record 49 of Set 9 | ekibastuz
# Processing Record 50 of Set 9 | jiangyou
# Processing Record 1 of Set 10 | laguna
# Processing Record 2 of Set 10 | arcachon
# Processing Record 3 of Set 10 | balabac
# Processing Record 4 of Set 10 | leshukonskoye
# Processing Record 5 of Set 10 | shakhtinsk
# Processing Record 6 of Set 10 | owosso
# Processing Record 7 of Set 10 | fort frances
# Processing Record 8 of Set 10 | poronaysk
# Processing Record 9 of Set 10 | dzitbalche
# Processing Record 10 of Set 10 | moron
# Processing Record 11 of Set 10 | gimli
# Processing Record 12 of Set 10 | barranca
# Processing Record 13 of Set 10 | ilheus
# Processing Record 14 of Set 10 | medowie
# Processing Record 15 of Set 10 | asadabad
# Processing Record 16 of Set 10 | gat
# Processing Record 17 of Set 10 | sokoni
# Processing Record 18 of Set 10 | najran
# Processing Record 19 of Set 10 | bud
# Processing Record 20 of Set 10 | kalmunai
# Processing Record 21 of Set 10 | verkhnyaya toyma
# Processing Record 22 of Set 10 | xingyi
# Processing Record 23 of Set 10 | vangaindrano
# Processing Record 24 of Set 10 | sijunjung
# Processing Record 25 of Set 10 | nuevitas
# Processing Record 26 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 10 | mbigou
# Processing Record 28 of Set 10 | mul
# Processing Record 29 of Set 10 | nemuro
# Processing Record 30 of Set 10 | kathu
# Processing Record 31 of Set 10 | niquero
# Processing Record 32 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 33 of Set 10 | kumluca
# Processing Record 34 of Set 10 | zhangye
# Processing Record 35 of Set 10 | srednekolymsk
# Processing Record 36 of Set 10 | tirat karmel
# Processing Record 37 of Set 10 | san luis
# Processing Record 38 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 10 | hirara
# Processing Record 40 of Set 10 | sangar
# Processing Record 41 of Set 10 | ibra
# Processing Record 42 of Set 10 | puerto colombia
# Processing Record 43 of Set 10 | eha amufu
# Processing Record 44 of Set 10 | kloulklubed
# Processing Record 45 of Set 10 | maua
# Processing Record 46 of Set 10 | brae
# Processing Record 47 of Set 10 | kyabe
# Processing Record 48 of Set 10 | kanchipuram
# Processing Record 49 of Set 10 | yomitan
# City not found. Skipping...
# Processing Record 50 of Set 10 | north battleford
# Processing Record 1 of Set 11 | tawnat
# City not found. Skipping...
# Processing Record 2 of Set 11 | gushikawa
# Processing Record 3 of Set 11 | iquitos
# Processing Record 4 of Set 11 | aranos
# Processing Record 5 of Set 11 | mount isa
# Processing Record 6 of Set 11 | dzilam gonzalez
# Processing Record 7 of Set 11 | camopi
# Processing Record 8 of Set 11 | kysyl-syr
# Processing Record 9 of Set 11 | baiao
# Processing Record 10 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 11 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 11 | okato
# Processing Record 13 of Set 11 | dongsheng
# Processing Record 14 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 11 | monte alegre de minas
# Processing Record 16 of Set 11 | stryn
# Processing Record 17 of Set 11 | loreto
# Processing Record 18 of Set 11 | mezen
# Processing Record 19 of Set 11 | bestobe
# Processing Record 20 of Set 11 | veraval
# Processing Record 21 of Set 11 | arlit
# Processing Record 22 of Set 11 | te anau
# Processing Record 23 of Set 11 | barra patuca
# Processing Record 24 of Set 11 | saposoa
# Processing Record 25 of Set 11 | lagos
# Processing Record 26 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 11 | hecun
# Processing Record 28 of Set 11 | polis
# Processing Record 29 of Set 11 | port lincoln
# Processing Record 30 of Set 11 | quievrain
# Processing Record 31 of Set 11 | tagusao
# Processing Record 32 of Set 11 | fare
# Processing Record 33 of Set 11 | falkoping
# City not found. Skipping...
# Processing Record 34 of Set 11 | tandil
# Processing Record 35 of Set 11 | guangyuan
# Processing Record 36 of Set 11 | leua
# Processing Record 37 of Set 11 | belyy yar
# Processing Record 38 of Set 11 | partizanskoye
# Processing Record 39 of Set 11 | avera
# Processing Record 40 of Set 11 | berlevag
# Processing Record 41 of Set 11 | murashi
# Processing Record 42 of Set 11 | sao luis do quitunde
# Processing Record 43 of Set 11 | dinajpur
# Processing Record 44 of Set 11 | san joaquin
# Processing Record 45 of Set 11 | jumla
# Processing Record 46 of Set 11 | zhigansk
# Processing Record 47 of Set 11 | moussoro
# Processing Record 48 of Set 11 | mae hong son
# Processing Record 49 of Set 11 | nizhniy kuranakh
# Processing Record 50 of Set 11 | wajima
# Processing Record 1 of Set 12 | lakefield
# Processing Record 2 of Set 12 | gavrilovka vtoraya
# Processing Record 3 of Set 12 | paita
# Processing Record 4 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 12 | oskarshamn
# Processing Record 6 of Set 12 | playa vicente
# Processing Record 7 of Set 12 | tondela
# Processing Record 8 of Set 12 | havelock
# Processing Record 9 of Set 12 | rawson
# Processing Record 10 of Set 12 | flinders
# Processing Record 11 of Set 12 | kulachi
# Processing Record 12 of Set 12 | monrovia
# Processing Record 13 of Set 12 | mutare
# Processing Record 14 of Set 12 | taltal
# Processing Record 15 of Set 12 | burica
# City not found. Skipping...
# Processing Record 16 of Set 12 | kudahuvadhoo
# Processing Record 17 of Set 12 | atar
# Processing Record 18 of Set 12 | bima
# Processing Record 19 of Set 12 | caravelas
# Processing Record 20 of Set 12 | nikolsk
# Processing Record 21 of Set 12 | san juan
# Processing Record 22 of Set 12 | newburgh
# Processing Record 23 of Set 12 | valkeakoski
# Processing Record 24 of Set 12 | touros
# Processing Record 25 of Set 12 | hami
# Processing Record 26 of Set 12 | yialos
# City not found. Skipping...
# Processing Record 27 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 28 of Set 12 | tokur
# Processing Record 29 of Set 12 | teguldet
# Processing Record 30 of Set 12 | sibolga
# Processing Record 31 of Set 12 | peleduy
# Processing Record 32 of Set 12 | riyadh
# Processing Record 33 of Set 12 | pemangkat
# Processing Record 34 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 35 of Set 12 | ishigaki
# Processing Record 36 of Set 12 | vostok
# Processing Record 37 of Set 12 | byron bay
# Processing Record 38 of Set 12 | edd
# Processing Record 39 of Set 12 | guadalupe y calvo
# Processing Record 40 of Set 12 | ruangwa
# Processing Record 41 of Set 12 | lannion
# Processing Record 42 of Set 12 | jardim
# Processing Record 43 of Set 12 | antalaha
# Processing Record 44 of Set 12 | moose factory
# Processing Record 45 of Set 12 | turukhansk
# Processing Record 46 of Set 12 | lompoc
# Processing Record 47 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 12 | sao jose da coroa grande
# Processing Record 49 of Set 12 | boa vista
# Processing Record 50 of Set 12 | sibu
# Processing Record 1 of Set 13 | pangai
# Processing Record 2 of Set 13 | snezhnogorsk
# Processing Record 3 of Set 13 | maghar
# Processing Record 4 of Set 13 | qasigiannguit
# Processing Record 5 of Set 13 | san buenaventura
# Processing Record 6 of Set 13 | novobirilyussy
# Processing Record 7 of Set 13 | klaksvik
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 555

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Hobart      AU -42.8794  147.3294     43.05        84          14
# 1         Isangel      VU -19.5500  169.2667     78.30        83         100
# 2        Luderitz      NA -26.6481   15.1594     61.30        89           1
# 3  Malyye Derbety      RU  47.9547   44.6808     45.46        74         100
# 4       Hithadhoo      MV  -0.6000   73.0833     81.72        78          78
# 5         Mataura      NZ -46.1927  168.8643     57.47        96          99
# 6           Roald      NO  62.5833    6.1333     39.34        60          75
# 7          Atuona      PF  -9.8000 -139.0333     78.28        74           4
# 8           Kapaa      US  22.0752 -159.3190     66.18        82          40
# 9     Tuktoyaktuk      CA  69.4541 -133.0374    -22.00        69           1
#
#    Wind Speed Current Description
# 0        1.01          few clouds
# 1        8.46     overcast clouds
# 2        4.07           clear sky
# 3       12.08     overcast clouds
# 4       12.64       broken clouds
# 5        3.44          light rain
# 6       13.80       broken clouds
# 7       18.41           clear sky
# 8        1.99          light rain
# 9        3.44           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
